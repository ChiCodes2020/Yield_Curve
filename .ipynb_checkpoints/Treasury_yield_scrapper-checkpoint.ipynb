# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# we wanna get the first <table> tag
#and then the second <table> tag class = t-chart
#<tbody> tag
# tr.evenrow (horizonal) are the even rows. You want to get the last one
# td.text_view_data gives the date and the amount of yield (13 columns)

# %%
# plot. save figure
#each line can represent the month
#date on the x-axis
#

# %%
#convert sting values to integers using pandas

# %%
def scrape():
    req = requests.get('https://www.treasury.gov/resource-center/data-chart-center/interest-rates/Pages/TextView.aspx?data=yield')
    content = req.text
    soup = BeautifulSoup(content, "lxml")
    
    treasury_table= soup.find("table", attrs={"class": "t-chart"})
    treasury_data = treasury_table.find_all("tr")
    
    
    header =["Date", "1Mo", "2Mo", "3Mo", "6Mo", "1Yr", "2Yr", "3Yr", "5Yr", "7Yr", "10Yr", "20Yr", "30Yr"]

    treasury_table= soup.find("table", attrs={"class": "t-chart"})
    

    trs = treasury_table.find_all("tr")

    data = []
    for tr in trs:
        tds = tr.findAll("td")
        row_empty=[]
        for td in tds:
            td_text = td.text.strip()
            row_empty.append(td_text)
        data.append(row_empty)
    final_data = data[1:]
    data_frame = pd.DataFrame(final_data, columns = header)
    data_frame[["1Mo", "2Mo", "3Mo", "6Mo", "1Yr", "2Yr", "3Yr", "5Yr", "7Yr", "10Yr", "20Yr", "30Yr"]] = data_frame[["1Mo", "2Mo", "3Mo", "6Mo", "1Yr", "2Yr", "3Yr", "5Yr", "7Yr", "10Yr", "20Yr", "30Yr"]].apply(pd.to_numeric)
    return data_frame

# %%
df =scrape()
df
# Out:
#         Date   1Mo   2Mo   3Mo   6Mo   1Yr   2Yr   3Yr   5Yr   7Yr  10Yr  \
# 0   04/01/21  0.02  0.02  0.02  0.04  0.06  0.17  0.35  0.90  1.37  1.69
# 1   04/02/21  0.02  0.02  0.02  0.04  0.07  0.19  0.39  0.97  1.42  1.72
# 2   04/05/21  0.03  0.02  0.03  0.04  0.06  0.17  0.37  0.94  1.40  1.73
# 3   04/06/21  0.02  0.02  0.02  0.04  0.06  0.16  0.35  0.88  1.34  1.67
# 4   04/07/21  0.01  0.02  0.02  0.04  0.06  0.16  0.34  0.87  1.34  1.68
# 5   04/08/21  0.02  0.02  0.01  0.04  0.05  0.14  0.33  0.85  1.30  1.64
# 6   04/09/21  0.02  0.01  0.02  0.03  0.06  0.16  0.35  0.87  1.33  1.67
# 7   04/12/21  0.02  0.02  0.02  0.04  0.06  0.18  0.38  0.89  1.35  1.69
# 8   04/13/21  0.03  0.02  0.03  0.05  0.06  0.16  0.35  0.85  1.29  1.64
# 9   04/14/21  0.02  0.02  0.02  0.04  0.06  0.16  0.35  0.87  1.31  1.64
# 10  04/15/21  0.02  0.01  0.02  0.04  0.06  0.16  0.32  0.81  1.24  1.56
# 11  04/16/21  0.02  0.02  0.02  0.04  0.06  0.16  0.34  0.84  1.26  1.59
# 12  04/19/21  0.01  0.02  0.02  0.04  0.08  0.16  0.34  0.85  1.28  1.61
# 13  04/20/21  0.01  0.02  0.03  0.04  0.07  0.15  0.31  0.81  1.25  1.58
# 14  04/21/21  0.00  0.02  0.03  0.04  0.07  0.15  0.32  0.81  1.24  1.57
# 15  04/22/21  0.02  0.02  0.03  0.04  0.06  0.16  0.32  0.81  1.24  1.57
# 16  04/23/21  0.01  0.02  0.03  0.03  0.07  0.16  0.34  0.83  1.26  1.58
# 17  04/26/21  0.02  0.02  0.03  0.04  0.06  0.18  0.35  0.85  1.27  1.58
# 18  04/27/21  0.01  0.02  0.01  0.04  0.06  0.17  0.36  0.88  1.32  1.63
# 19  04/28/21  0.01  0.01  0.01  0.04  0.05  0.17  0.35  0.86  1.31  1.63
# 20  04/29/21  0.01  0.01  0.01  0.04  0.05  0.16  0.35  0.86  1.32  1.65
# 21  04/30/21  0.01  0.02  0.01  0.03  0.05  0.16  0.35  0.86  1.32  1.65
#
#     20Yr  30Yr
# 0   2.24  2.34
# 1   2.27  2.35
# 2   2.28  2.36
# 3   2.24  2.32
# 4   2.26  2.35
# 5   2.22  2.32
# 6   2.23  2.34
# 7   2.24  2.34
# 8   2.21  2.32
# 9   2.22  2.32
# 10  2.13  2.23
# 11  2.15  2.26
# 12  2.18  2.29
# 13  2.16  2.27
# 14  2.16  2.26
# 15  2.13  2.24
# 16  2.14  2.25
# 17  2.13  2.24
# 18  2.18  2.29
# 19  2.19  2.29
# 20  2.20  2.31
# 21  2.19  2.30

# %%
maturity = list(df)
maturity_date = date[1:]
maturity_date
# Out:
# ['2Mo',
#  '3Mo',
#  '6Mo',
#  '1Yr',
#  '2Yr',
#  '3Yr',
#  '5Yr',
#  '7Yr',
#  '10Yr',
#  '20Yr',
#  '30Yr']

# %%
df[maturity_date].keys()
# Out:
# Index(['2Mo', '3Mo', '6Mo', '1Yr', '2Yr', '3Yr', '5Yr', '7Yr', '10Yr', '20Yr',
#        '30Yr'],
#       dtype='object')

# %%
df[maturity_date].values
# Out:
# array([[0.02, 0.02, 0.04, 0.06, 0.17, 0.35, 0.9 , 1.37, 1.69, 2.24, 2.34],
#        [0.02, 0.02, 0.04, 0.07, 0.19, 0.39, 0.97, 1.42, 1.72, 2.27, 2.35],
#        [0.02, 0.03, 0.04, 0.06, 0.17, 0.37, 0.94, 1.4 , 1.73, 2.28, 2.36],
#        [0.02, 0.02, 0.04, 0.06, 0.16, 0.35, 0.88, 1.34, 1.67, 2.24, 2.32],
#        [0.02, 0.02, 0.04, 0.06, 0.16, 0.34, 0.87, 1.34, 1.68, 2.26, 2.35],
#        [0.02, 0.01, 0.04, 0.05, 0.14, 0.33, 0.85, 1.3 , 1.64, 2.22, 2.32],
#        [0.01, 0.02, 0.03, 0.06, 0.16, 0.35, 0.87, 1.33, 1.67, 2.23, 2.34],
#        [0.02, 0.02, 0.04, 0.06, 0.18, 0.38, 0.89, 1.35, 1.69, 2.24, 2.34],
#        [0.02, 0.03, 0.05, 0.06, 0.16, 0.35, 0.85, 1.29, 1.64, 2.21, 2.32],
#        [0.02, 0.02, 0.04, 0.06, 0.16, 0.35, 0.87, 1.31, 1.64, 2.22, 2.32],
#        [0.01, 0.02, 0.04, 0.06, 0.16, 0.32, 0.81, 1.24, 1.56, 2.13, 2.23],
#        [0.02, 0.02, 0.04, 0.06, 0.16, 0.34, 0.84, 1.26, 1.59, 2.15, 2.26],
#        [0.02, 0.02, 0.04, 0.08, 0.16, 0.34, 0.85, 1.28, 1.61, 2.18, 2.29],
#        [0.02, 0.03, 0.04, 0.07, 0.15, 0.31, 0.81, 1.25, 1.58, 2.16, 2.27],
#        [0.02, 0.03, 0.04, 0.07, 0.15, 0.32, 0.81, 1.24, 1.57, 2.16, 2.26],
#        [0.02, 0.03, 0.04, 0.06, 0.16, 0.32, 0.81, 1.24, 1.57, 2.13, 2.24],
#        [0.02, 0.03, 0.03, 0.07, 0.16, 0.34, 0.83, 1.26, 1.58, 2.14, 2.25],
#        [0.02, 0.03, 0.04, 0.06, 0.18, 0.35, 0.85, 1.27, 1.58, 2.13, 2.24],
#        [0.02, 0.01, 0.04, 0.06, 0.17, 0.36, 0.88, 1.32, 1.63, 2.18, 2.29],
#        [0.01, 0.01, 0.04, 0.05, 0.17, 0.35, 0.86, 1.31, 1.63, 2.19, 2.29],
#        [0.01, 0.01, 0.04, 0.05, 0.16, 0.35, 0.86, 1.32, 1.65, 2.2 , 2.31],
#        [0.02, 0.01, 0.03, 0.05, 0.16, 0.35, 0.86, 1.32, 1.65, 2.19, 2.3 ]])

# %%
dictionaryObject = df.to_dict()
dictionaryObject
# Out:
# {'Date': {0: '04/01/21',
#   1: '04/02/21',
#   2: '04/05/21',
#   3: '04/06/21',
#   4: '04/07/21',
#   5: '04/08/21',
#   6: '04/09/21',
#   7: '04/12/21',
#   8: '04/13/21',
#   9: '04/14/21',
#   10: '04/15/21',
#   11: '04/16/21',
#   12: '04/19/21',
#   13: '04/20/21',
#   14: '04/21/21',
#   15: '04/22/21',
#   16: '04/23/21',
#   17: '04/26/21',
#   18: '04/27/21',
#   19: '04/28/21',
#   20: '04/29/21',
#   21: '04/30/21'},
#  '1Mo': {0: 0.02,
#   1: 0.02,
#   2: 0.03,
#   3: 0.02,
#   4: 0.01,
#   5: 0.02,
#   6: 0.02,
#   7: 0.02,
#   8: 0.03,
#   9: 0.02,
#   10: 0.02,
#   11: 0.02,
#   12: 0.01,
#   13: 0.01,
#   14: 0.0,
#   15: 0.02,
#   16: 0.01,
#   17: 0.02,
#   18: 0.01,
#   19: 0.01,
#   20: 0.01,
#   21: 0.01},
#  '2Mo': {0: 0.02,
#   1: 0.02,
#   2: 0.02,
#   3: 0.02,
#   4: 0.02,
#   5: 0.02,
#   6: 0.01,
#   7: 0.02,
#   8: 0.02,
#   9: 0.02,
#   10: 0.01,
#   11: 0.02,
#   12: 0.02,
#   13: 0.02,
#   14: 0.02,
#   15: 0.02,
#   16: 0.02,
#   17: 0.02,
#   18: 0.02,
#   19: 0.01,
#   20: 0.01,
#   21: 0.02},
#  '3Mo': {0: 0.02,
#   1: 0.02,
#   2: 0.03,
#   3: 0.02,
#   4: 0.02,
#   5: 0.01,
#   6: 0.02,
#   7: 0.02,
#   8: 0.03,
#   9: 0.02,
#   10: 0.02,
#   11: 0.02,
#   12: 0.02,
#   13: 0.03,
#   14: 0.03,
#   15: 0.03,
#   16: 0.03,
#   17: 0.03,
#   18: 0.01,
#   19: 0.01,
#   20: 0.01,
#   21: 0.01},
#  '6Mo': {0: 0.04,
#   1: 0.04,
#   2: 0.04,
#   3: 0.04,
#   4: 0.04,
#   5: 0.04,
#   6: 0.03,
#   7: 0.04,
#   8: 0.05,
#   9: 0.04,
#   10: 0.04,
#   11: 0.04,
#   12: 0.04,
#   13: 0.04,
#   14: 0.04,
#   15: 0.04,
#   16: 0.03,
#   17: 0.04,
#   18: 0.04,
#   19: 0.04,
#   20: 0.04,
#   21: 0.03},
#  '1Yr': {0: 0.06,
#   1: 0.07,
#   2: 0.06,
#   3: 0.06,
#   4: 0.06,
#   5: 0.05,
#   6: 0.06,
#   7: 0.06,
#   8: 0.06,
#   9: 0.06,
#   10: 0.06,
#   11: 0.06,
#   12: 0.08,
#   13: 0.07,
#   14: 0.07,
#   15: 0.06,
#   16: 0.07,
#   17: 0.06,
#   18: 0.06,
#   19: 0.05,
#   20: 0.05,
#   21: 0.05},
#  '2Yr': {0: 0.17,
#   1: 0.19,
#   2: 0.17,
#   3: 0.16,
#   4: 0.16,
#   5: 0.14,
#   6: 0.16,
#   7: 0.18,
#   8: 0.16,
#   9: 0.16,
#   10: 0.16,
#   11: 0.16,
#   12: 0.16,
#   13: 0.15,
#   14: 0.15,
#   15: 0.16,
#   16: 0.16,
#   17: 0.18,
#   18: 0.17,
#   19: 0.17,
#   20: 0.16,
#   21: 0.16},
#  '3Yr': {0: 0.35,
#   1: 0.39,
#   2: 0.37,
#   3: 0.35,
#   4: 0.34,
#   5: 0.33,
#   6: 0.35,
#   7: 0.38,
#   8: 0.35,
#   9: 0.35,
#   10: 0.32,
#   11: 0.34,
#   12: 0.34,
#   13: 0.31,
#   14: 0.32,
#   15: 0.32,
#   16: 0.34,
#   17: 0.35,
#   18: 0.36,
#   19: 0.35,
#   20: 0.35,
#   21: 0.35},
#  '5Yr': {0: 0.9,
#   1: 0.97,
#   2: 0.94,
#   3: 0.88,
#   4: 0.87,
#   5: 0.85,
#   6: 0.87,
#   7: 0.89,
#   8: 0.85,
#   9: 0.87,
#   10: 0.81,
#   11: 0.84,
#   12: 0.85,
#   13: 0.81,
#   14: 0.81,
#   15: 0.81,
#   16: 0.83,
#   17: 0.85,
#   18: 0.88,
#   19: 0.86,
#   20: 0.86,
#   21: 0.86},
#  '7Yr': {0: 1.37,
#   1: 1.42,
#   2: 1.4,
#   3: 1.34,
#   4: 1.34,
#   5: 1.3,
#   6: 1.33,
#   7: 1.35,
#   8: 1.29,
#   9: 1.31,
#   10: 1.24,
#   11: 1.26,
#   12: 1.28,
#   13: 1.25,
#   14: 1.24,
#   15: 1.24,
#   16: 1.26,
#   17: 1.27,
#   18: 1.32,
#   19: 1.31,
#   20: 1.32,
#   21: 1.32},
#  '10Yr': {0: 1.69,
#   1: 1.72,
#   2: 1.73,
#   3: 1.67,
#   4: 1.68,
#   5: 1.64,
#   6: 1.67,
#   7: 1.69,
#   8: 1.64,
#   9: 1.64,
#   10: 1.56,
#   11: 1.59,
#   12: 1.61,
#   13: 1.58,
#   14: 1.57,
#   15: 1.57,
#   16: 1.58,
#   17: 1.58,
#   18: 1.63,
#   19: 1.63,
#   20: 1.65,
#   21: 1.65},
#  '20Yr': {0: 2.24,
#   1: 2.27,
#   2: 2.28,
#   3: 2.24,
#   4: 2.26,
#   5: 2.22,
#   6: 2.23,
#   7: 2.24,
#   8: 2.21,
#   9: 2.22,
#   10: 2.13,
#   11: 2.15,
#   12: 2.18,
#   13: 2.16,
#   14: 2.16,
#   15: 2.13,
#   16: 2.14,
#   17: 2.13,
#   18: 2.18,
#   19: 2.19,
#   20: 2.2,
#   21: 2.19},
#  '30Yr': {0: 2.34,
#   1: 2.35,
#   2: 2.36,
#   3: 2.32,
#   4: 2.35,
#   5: 2.32,
#   6: 2.34,
#   7: 2.34,
#   8: 2.32,
#   9: 2.32,
#   10: 2.23,
#   11: 2.26,
#   12: 2.29,
#   13: 2.27,
#   14: 2.26,
#   15: 2.24,
#   16: 2.25,
#   17: 2.24,
#   18: 2.29,
#   19: 2.29,
#   20: 2.31,
#   21: 2.3}}

# %%
date = df["Date"]
rate_by_maturity_date = dictionaryObject

fig, ax = plt.subplots()
ax.stackplot(date, rate_by_maturity_date.values(),
             labels=rate_by_maturity_date.keys())
ax.legend(loc='upper left')
ax.set_title('Treasury Yield Maturity by Date')
ax.set_xlabel('Date')
ax.set_ylabel('Number of people (millions)')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-6c49eabd4335> in <module>
#       3
#       4 fig, ax = plt.subplots()
# ----> 5 ax.stackplot(date, rate_by_maturity_date.values(),
#       6              labels=rate_by_maturity_date.keys())
#       7 ax.legend(loc='upper left')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/stackplot.py in stackplot(axes, x, labels, colors, baseline, *args, **kwargs)
#     104     # Color between x = 0 and the first array.
#     105     color = axes._get_lines.get_next_color()
# --> 106     coll = axes.fill_between(x, first_line, stack[0, :],
#     107                              facecolor=color, label=next(labels, None),
#     108                              **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in fill_between(self, x, y1, y2, where, interpolate, step, **kwargs)
#    5150         x = ma.masked_invalid(self.convert_xunits(x))
#    5151         y1 = ma.masked_invalid(self.convert_yunits(y1))
# -> 5152         y2 = ma.masked_invalid(self.convert_yunits(y2))
#    5153
#    5154         for name, array in [('x', x), ('y1', y1), ('y2', y2)]:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/ma/core.py in masked_invalid(a, copy)
#    2375         cls = type(a)
#    2376     else:
# -> 2377         condition = ~(np.isfinite(a))
#    2378         cls = MaskedArray
#    2379     result = a.view(cls)
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
def plot():
    df =scrape()
